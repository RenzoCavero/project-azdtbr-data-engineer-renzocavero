# %%
# -- CREATE WIDGET & ----------
dbutils.widgets.removeAll()
dbutils.widgets.text("storageName", "adlsrenzocavero", "Storage Account Name")
storage_name = dbutils.widgets.get("storageName")

print(f"storageName = {storage_name}")

# %%
# %sql
SHOW STORAGE CREDENTIALS;

# %%
# %sql
-- CREATE CATALOG (definiendo managed location explícita)
CREATE CATALOG IF NOT EXISTS catalog_project
MANAGED LOCATION 'abfss://bronze@adlsrenzocavero.dfs.core.windows.net/';

-- CREATE SCHEMAS
CREATE SCHEMA IF NOT EXISTS catalog_project.bronze;
CREATE SCHEMA IF NOT EXISTS catalog_project.silver;
CREATE SCHEMA IF NOT EXISTS catalog_project.golden;

-- CREATE EXTERNAL LOCATIONS
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-raw`
URL 'abfss://raw@adlsrenzocavero.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `ws_azure_databricks_data_engineer`);

CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-bronze`
URL 'abfss://bronze@adlsrenzocavero.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `ws_azure_databricks_data_engineer`);

CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-silver`
URL 'abfss://silver@adlsrenzocavero.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `ws_azure_databricks_data_engineer`);

CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-golden`
URL 'abfss://golden@adlsrenzocavero.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `ws_azure_databricks_data_engineer`);
