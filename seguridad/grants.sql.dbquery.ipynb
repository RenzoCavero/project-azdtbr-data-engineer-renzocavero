-- %%
CREATE GROUP IF NOT EXISTS renzo_project_users;

-- Reemplazar por correos de usuarios:
ALTER GROUP renzo_project_users ADD USER 'renzos.caveroc@gmail.com';
ALTER GROUP renzo_project_users ADD USER 'renzos.caveroc_gmail.com#EXT#@renzoscaverocgmail.onmicrosoft.com';

-- Catalog
GRANT USE CATALOG ON CATALOG catalog_dev TO `renzo_project_users`;

-- Schemas Medallion
GRANT USE SCHEMA, CREATE, SELECT, MODIFY
ON SCHEMA catalog_dev.bronze
TO `renzo_project_users`;

GRANT USE SCHEMA, CREATE, SELECT, MODIFY
ON SCHEMA catalog_dev.silver
TO `renzo_project_users`;

GRANT USE SCHEMA, CREATE, SELECT, MODIFY
ON SCHEMA catalog_dev.gold
TO `renzo_project_users`;

-- External Locations
GRANT READ FILES, WRITE FILES
ON EXTERNAL LOCATION `extl-bronze`
TO `renzo_project_users`;

GRANT READ FILES, WRITE FILES
ON EXTERNAL LOCATION `extl-silver`
TO `renzo_project_users`;

GRANT READ FILES, WRITE FILES
ON EXTERNAL LOCATION `extl-gold`
TO `renzo_project_users`;
