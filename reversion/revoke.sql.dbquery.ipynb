-- %%
-- Catalog
REVOKE USE CATALOG ON CATALOG catalog_dev FROM `renzo_project_users`;

-- Schemas Medallion
REVOKE USE SCHEMA, CREATE, SELECT, MODIFY
ON SCHEMA catalog_dev.bronze
FROM `renzo_project_users`;

REVOKE USE SCHEMA, CREATE, SELECT, MODIFY
ON SCHEMA catalog_dev.silver
FROM `renzo_project_users`;

REVOKE USE SCHEMA, CREATE, SELECT, MODIFY
ON SCHEMA catalog_dev.gold
FROM `renzo_project_users`;

-- External Locations
REVOKE READ FILES, WRITE FILES
ON EXTERNAL LOCATION `extl-bronze`
FROM `renzo_project_users`;

REVOKE READ FILES, WRITE FILES
ON EXTERNAL LOCATION `extl-silver`
FROM `renzo_project_users`;

REVOKE READ FILES, WRITE FILES
ON EXTERNAL LOCATION `extl-gold`
FROM `renzo_project_users`;
