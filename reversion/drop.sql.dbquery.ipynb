-- %%
-- GOLD
DROP TABLE IF EXISTS catalog_dev.gold.agg_customers_by_age_group;
DROP TABLE IF EXISTS catalog_dev.gold.agg_customers_by_gender;
DROP TABLE IF EXISTS catalog_dev.gold.agg_customers_by_segmentation;
DROP TABLE IF EXISTS catalog_dev.gold.agg_sales_by_month;
DROP TABLE IF EXISTS catalog_dev.gold.agg_sales_by_segment;
DROP TABLE IF EXISTS catalog_dev.gold.dim_customers;
DROP TABLE IF EXISTS catalog_dev.gold.fact_sales;
DROP TABLE IF EXISTS catalog_dev.gold.kpi_customers;
DROP TABLE IF EXISTS catalog_dev.gold.kpi_overview;

-- SILVER
DROP TABLE IF EXISTS catalog_dev.silver.customers_silver;
DROP TABLE IF EXISTS catalog_dev.silver.ecommerce_sales_prediction_silver;

-- BRONZE
DROP TABLE IF EXISTS catalog_dev.bronze.customers_bronze;
DROP TABLE IF EXISTS catalog_dev.bronze.ecommerce_sales_prediction_bronze;

-- SCHEMAS
DROP SCHEMA IF EXISTS catalog_dev.gold CASCADE;
DROP SCHEMA IF EXISTS catalog_dev.silver CASCADE;
DROP SCHEMA IF EXISTS catalog_dev.bronze CASCADE;

-- CATALOG (opcional)
-- DROP CATALOG IF EXISTS catalog_dev CASCADE;

-- EXTERNAL LOCATIONS (opcional)
-- DROP EXTERNAL LOCATION IF EXISTS `extl-bronze`;
-- DROP EXTERNAL LOCATION IF EXISTS `extl-silver`;
-- DROP EXTERNAL LOCATION IF EXISTS `extl-gold`;
